# %%
import requests, bs4
import pandas as pd

# %%
titles = []
articles = []
url = 'https://inshorts.com/en/read'
res = requests.get(url)
if res.status_code == requests.codes.ok:
    ressoup = bs4.BeautifulSoup(res.text, 'lxml')
    elems = ressoup.select('div.news-card.z-depth-1')
    for e in elems:
        post = e.getText().strip().split('\n')
        titles.append(post[0])
        articles.append(post[8])
else:
    print('Something went wrong')

# %%
pd.DataFrame({'Title': titles,
             'Article':articles})
# Out:
#                                                 Title  \
# 0   Kanika Kapoor issues 1st statement after recov...
# 1   Jail for up to 3 years for blocking funerals o...
# 2   You almost finished my son's career: Chris Bro...
# 3   Magician forced to turn vegetable vendor in Ra...
# 4   2 policemen die of COVID-19 in 24 hours, Mumba...
# 5   Truck driver plays cards, tambola with neighbo...
# 6   India won't be blamed if we don't export medic...
# 7   B'luru hospital uses remote-controlled trolley...
# 8   15 more CRPF personnel test positive for coron...
# 9   Delhi's Babu Jagjivan Ram hospital shut after ...
# 10  Over 10 pollution hotspots in Delhi, Mumbai tu...
# 11  J'khand fruit sellers told to remove 'VHP appr...
# 12  Man commits suicide by hanging himself in his ...
# 13  China confiscates 8.9 crore 'poor quality' fac...
# 14  Beijing bans 'uncivilised' behaviour amid coro...
# 15  Tata Steel looking to get ₹4,718 cr bailout fr...
# 16  We're appalled: Everton after Moise Kean seen ...
# 17  916 foreign workers test COVID-19 +ve in S'por...
# 18  How can India keep Ashwin out from shorter for...
# 19  T20 WC win would've brought generational shift...
# 20  I ended up crying: Hima Das on meeting 'role m...
# 21  Boeing terminates $4.2 billion deal to buy 80%...
#
#                                               Article
# 0   Singer Kanika Kapoor, who has recovered from c...
# 1   Blocking the "dignified" burial or cremation o...
# 2   Ex-India all-rounder Yuvraj Singh, during a re...
# 3   Raju Mahor alias RJ Samrat Jadugar, a 38-year-...
# 4   A 52-year-old head constable and a 57-year-old...
# 5   A truck driver invited neighbours to his house...
# 6   PM Narendra Modi, during his 'Mann Ki Baat' ad...
# 7   Victoria Hospital in Bengaluru, Karnataka has ...
# 8   Fifteen Central Reserve Police Force (CRPF) pe...
# 9   Medical services at Babu Jagjivan Ram Memorial...
# 10  Over 10 pollution hotspots in Mumbai and Delhi...
# 11  Police in Jamshedpur, Jharkhand said preventiv...
# 12  A Mumbai autorickshaw driver committed suicide...
# 13  China has confiscated 8.9 crore poor quality f...
# 14  Authorities in Beijing, China's capital, on Su...
# 15  Tata Steel's UK arm is looking to get over ₹4,...
# 16  After pictures showing Everton striker Moise K...
# 17  Singapore on Sunday reported 931 cases of coro...
# 18  Ex-Pakistan spinner Saqlain Mushtaq has said t...
# 19  Talking about women's cricket, ex-India Women ...
# 20  During an Instagram live session with India ba...
# 21  Boeing has terminated a $4.2-billion deal to b...
