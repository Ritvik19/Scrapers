# %% [markdown]
# # Libraries

# %%
import requests, pandas as pd
from datetime import datetime

# %% [markdown]
# # API Request

# %%
API_KEY = '9ebf89f6b98f22841d3baf170a682bd2'
def APIRequest(mode, key, city):
    # current weather
    if mode == 0:
        return 'http://api.openweathermap.org/data/2.5/weather?q='+city+'&APPID='+key
    # 5 day forecast
    if mode == 1:
        return 'http://api.openweathermap.org/data/2.5/forecast?q='+city+'&APPID='+key

# %%
def weather(mode, key, city):
    res = requests.get(APIRequest(mode, key, city))
    data = res.json()
    if mode == 0:
        print(data['name'])
        print(f"Longitude: {data['coord']['lon']}")
        print(f"Latitude : {data['coord']['lat']}")
        print(f"Weather:\n\t{data['weather'][0]['main']}\n\t{data['weather'][0]['description']}")
        print(f"Temperature: {data['main']['temp'] - 273.15:.2f} degree celsius")
        print(f"Pressure   : {data['main']['pressure']} hecto pascal")
        print(f"Humidity   : {data['main']['humidity']} %")
        print(f"Wind Speed : {data['wind']['speed']} m/sec")
        print(f"Wind Direc : {data['wind']['deg']}")
    if mode == 1:
        print(data['city']['name'])
        print(f"Longitude: {data['city']['coord']['lon']}")
        print(f"Latitude : {data['city']['coord']['lat']}")
        for i in data['list']:
            print()
            print(datetime.fromtimestamp(i['dt']))
            print(f"Weather:\n\t{i['weather'][0]['main']}\n\t{i['weather'][0]['description']}")
            print(f"Temperature: {i['main']['temp'] - 273.15:.2f} degree celsius")
            print(f"Pressure   : {i['main']['pressure']} hecto pascal")
            print(f"Humidity   : {i['main']['humidity']} %")
            print(f"Wind Speed : {i['wind']['speed']} m/sec")
            print(f"Wind Direc : {i['wind']['deg']}")

# %%
weather(1, API_KEY, 'moradabad')
# Out:
# Moradabad
# Longitude: 78.7733
# Latitude : 28.8335
#
# 2019-06-07 17:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 43.45 degree celsius
# Pressure   : 999.5 hecto pascal
# Humidity   : 12 %
# Wind Speed : 4.2 m/sec
# Wind Direc : 280.944
#
# 2019-06-07 20:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 38.25 degree celsius
# Pressure   : 1000.32 hecto pascal
# Humidity   : 15 %
# Wind Speed : 2.62 m/sec
# Wind Direc : 315.852
#
# 2019-06-07 23:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 34.55 degree celsius
# Pressure   : 1001.28 hecto pascal
# Humidity   : 17 %
# Wind Speed : 1.16 m/sec
# Wind Direc : 40.274
#
# 2019-06-08 02:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 32.95 degree celsius
# Pressure   : 1000.91 hecto pascal
# Humidity   : 19 %
# Wind Speed : 0.34 m/sec
# Wind Direc : 57.516
#
# 2019-06-08 05:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 31.15 degree celsius
# Pressure   : 1001.15 hecto pascal
# Humidity   : 21 %
# Wind Speed : 2.4 m/sec
# Wind Direc : 106.205
#
# 2019-06-08 08:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 37.45 degree celsius
# Pressure   : 1002.54 hecto pascal
# Humidity   : 17 %
# Wind Speed : 3.33 m/sec
# Wind Direc : 107.086
#
# 2019-06-08 11:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 43.45 degree celsius
# Pressure   : 1001.69 hecto pascal
# Humidity   : 10 %
# Wind Speed : 2.39 m/sec
# Wind Direc : 186.637
#
# 2019-06-08 14:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 46.37 degree celsius
# Pressure   : 998.79 hecto pascal
# Humidity   : 6 %
# Wind Speed : 4.81 m/sec
# Wind Direc : 300.25
#
# 2019-06-08 17:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 45.45 degree celsius
# Pressure   : 996.36 hecto pascal
# Humidity   : 6 %
# Wind Speed : 6.13 m/sec
# Wind Direc : 307.852
#
# 2019-06-08 20:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 39.33 degree celsius
# Pressure   : 997.72 hecto pascal
# Humidity   : 10 %
# Wind Speed : 4.1 m/sec
# Wind Direc : 287.467
#
# 2019-06-08 23:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 36.31 degree celsius
# Pressure   : 998.59 hecto pascal
# Humidity   : 11 %
# Wind Speed : 3.28 m/sec
# Wind Direc : 316.431
#
# 2019-06-09 02:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 33.29 degree celsius
# Pressure   : 997.83 hecto pascal
# Humidity   : 15 %
# Wind Speed : 0.98 m/sec
# Wind Direc : 298.68
#
# 2019-06-09 05:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 31.56 degree celsius
# Pressure   : 998.18 hecto pascal
# Humidity   : 17 %
# Wind Speed : 3.09 m/sec
# Wind Direc : 80.782
#
# 2019-06-09 08:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 37.43 degree celsius
# Pressure   : 999.64 hecto pascal
# Humidity   : 19 %
# Wind Speed : 6.28 m/sec
# Wind Direc : 110.321
#
# 2019-06-09 11:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 43.42 degree celsius
# Pressure   : 999.18 hecto pascal
# Humidity   : 17 %
# Wind Speed : 4.83 m/sec
# Wind Direc : 137.777
#
# 2019-06-09 14:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 47.03 degree celsius
# Pressure   : 995.79 hecto pascal
# Humidity   : 8 %
# Wind Speed : 4.86 m/sec
# Wind Direc : 288.774
#
# 2019-06-09 17:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 46.65 degree celsius
# Pressure   : 993.42 hecto pascal
# Humidity   : 6 %
# Wind Speed : 6.6 m/sec
# Wind Direc : 302.543
#
# 2019-06-09 20:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 40.01 degree celsius
# Pressure   : 994.92 hecto pascal
# Humidity   : 8 %
# Wind Speed : 3.36 m/sec
# Wind Direc : 288.019
#
# 2019-06-09 23:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 36.73 degree celsius
# Pressure   : 995.51 hecto pascal
# Humidity   : 10 %
# Wind Speed : 2.81 m/sec
# Wind Direc : 302.587
#
# 2019-06-10 02:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 34.25 degree celsius
# Pressure   : 995.12 hecto pascal
# Humidity   : 11 %
# Wind Speed : 1.47 m/sec
# Wind Direc : 290.043
#
# 2019-06-10 05:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 31.55 degree celsius
# Pressure   : 996.46 hecto pascal
# Humidity   : 32 %
# Wind Speed : 5.86 m/sec
# Wind Direc : 105.414
#
# 2019-06-10 08:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 36.15 degree celsius
# Pressure   : 998.18 hecto pascal
# Humidity   : 39 %
# Wind Speed : 8.24 m/sec
# Wind Direc : 117.729
#
# 2019-06-10 11:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 42.02 degree celsius
# Pressure   : 997.08 hecto pascal
# Humidity   : 24 %
# Wind Speed : 4.62 m/sec
# Wind Direc : 141.201
#
# 2019-06-10 14:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 47.02 degree celsius
# Pressure   : 993.69 hecto pascal
# Humidity   : 10 %
# Wind Speed : 4.31 m/sec
# Wind Direc : 280.658
#
# 2019-06-10 17:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 47.31 degree celsius
# Pressure   : 991.72 hecto pascal
# Humidity   : 6 %
# Wind Speed : 5.8 m/sec
# Wind Direc : 300.244
#
# 2019-06-10 20:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 40.23 degree celsius
# Pressure   : 993.27 hecto pascal
# Humidity   : 9 %
# Wind Speed : 2.23 m/sec
# Wind Direc : 317.839
#
# 2019-06-10 23:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 37.28 degree celsius
# Pressure   : 993.83 hecto pascal
# Humidity   : 10 %
# Wind Speed : 1.62 m/sec
# Wind Direc : 239.278
#
# 2019-06-11 02:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 35.05 degree celsius
# Pressure   : 993.55 hecto pascal
# Humidity   : 12 %
# Wind Speed : 2.47 m/sec
# Wind Direc : 68.643
#
# 2019-06-11 05:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 32.93 degree celsius
# Pressure   : 995 hecto pascal
# Humidity   : 33 %
# Wind Speed : 5.44 m/sec
# Wind Direc : 103.666
#
# 2019-06-11 08:30:00
# Weather:
# 	Clouds
# 	scattered clouds
# Temperature: 37.06 degree celsius
# Pressure   : 997.15 hecto pascal
# Humidity   : 37 %
# Wind Speed : 7.04 m/sec
# Wind Direc : 119.963
#
# 2019-06-11 11:30:00
# Weather:
# 	Clouds
# 	scattered clouds
# Temperature: 42.55 degree celsius
# Pressure   : 996.19 hecto pascal
# Humidity   : 24 %
# Wind Speed : 4.5 m/sec
# Wind Direc : 137.737
#
# 2019-06-11 14:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 46.75 degree celsius
# Pressure   : 993.23 hecto pascal
# Humidity   : 12 %
# Wind Speed : 3.63 m/sec
# Wind Direc : 283.102
#
# 2019-06-11 17:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 46.64 degree celsius
# Pressure   : 991.97 hecto pascal
# Humidity   : 7 %
# Wind Speed : 5.69 m/sec
# Wind Direc : 264.917
#
# 2019-06-11 20:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 41.14 degree celsius
# Pressure   : 993.62 hecto pascal
# Humidity   : 14 %
# Wind Speed : 7.56 m/sec
# Wind Direc : 239.482
#
# 2019-06-11 23:30:00
# Weather:
# 	Clouds
# 	scattered clouds
# Temperature: 40.95 degree celsius
# Pressure   : 994.63 hecto pascal
# Humidity   : 11 %
# Wind Speed : 2.98 m/sec
# Wind Direc : 273.464
#
# 2019-06-12 02:30:00
# Weather:
# 	Clouds
# 	broken clouds
# Temperature: 37.27 degree celsius
# Pressure   : 994.22 hecto pascal
# Humidity   : 14 %
# Wind Speed : 3.05 m/sec
# Wind Direc : 110.294
#
# 2019-06-12 05:30:00
# Weather:
# 	Clouds
# 	broken clouds
# Temperature: 34.93 degree celsius
# Pressure   : 995.4 hecto pascal
# Humidity   : 34 %
# Wind Speed : 3.77 m/sec
# Wind Direc : 125.253
#
# 2019-06-12 08:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 38.95 degree celsius
# Pressure   : 997.23 hecto pascal
# Humidity   : 32 %
# Wind Speed : 5.75 m/sec
# Wind Direc : 115.959
#
# 2019-06-12 11:30:00
# Weather:
# 	Clear
# 	clear sky
# Temperature: 44.11 degree celsius
# Pressure   : 996.13 hecto pascal
# Humidity   : 19 %
# Wind Speed : 4.14 m/sec
# Wind Direc : 131.105
#
# 2019-06-12 14:30:00
# Weather:
# 	Clouds
# 	broken clouds
# Temperature: 43.44 degree celsius
# Pressure   : 993.48 hecto pascal
# Humidity   : 15 %
# Wind Speed : 1.26 m/sec
# Wind Direc : 197.416
